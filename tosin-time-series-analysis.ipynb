# %% [markdown]
# ## Install Libraries

# %%
# !pip install -q tensorflow=='2.18.0'

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, f1_score, recall_score
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Input, Multiply, Softmax, Layer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import tensorflow as tf
# Out:
# 2025-11-21 15:53:36.589203: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763740416.860420      48 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763740416.943744      48 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %% [markdown]
# ## Configuration

# %%
# Set random seeds for reproducibility
import os
import random

SEED = 0
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Configure TensorFlow for reproducibility
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_excel("tosin-time-series-data/FNCL.6.5.xlsx")

# %% [markdown]
# ## Data Preprocessing

# %%
df = df.sort_values(by=['Dates']).reset_index(drop=True)

# Calculate price diff and movement
df["price_diff"] = df["FNCL 6.5 2022 FL Mtge"].diff()

def encode_movement(x):
    if x > 0:
        return 1  # up
    elif x < 0:
        return 0  # down
    else:
        return -1  # flat (to be removed)

df["movement"] = df["price_diff"].apply(
    lambda x: encode_movement(x) if pd.notnull(x) else -1
)

# Remove rows with NaN prices and flat movements
df = df[df["FNCL 6.5 2022 FL Mtge"].notna()].reset_index(drop=True)
df = df[df["movement"] != -1].reset_index(drop=True)

print(f"Dataset shape after removing NaNs and flats: {df.shape}")
print(f"Movement distribution - Up (1): {(df['movement']==1).sum()}, Down (0): {(df['movement']==0).sum()}")
# Out:
# Dataset shape after removing NaNs and flats: (640, 4)
# Movement distribution - Up (1): 322, Down (0): 318

# %% [markdown]
# ## Feature Engineering

# %%
def create_features(data, lags=[1, 2, 3, 5, 10, 21]):
    """Create lagged features and technical indicators"""
    features_df = data.copy()
    price_col = "FNCL 6.5 2022 FL Mtge"
    
    # Lagged prices
    for lag in lags:
        features_df[f'price_lag_{lag}'] = features_df[price_col].shift(lag)
    
    # Lagged price differences
    for lag in [1, 2, 3, 5]:
        features_df[f'diff_lag_{lag}'] = features_df['price_diff'].shift(lag)
    
    # Rolling statistics
    for window in [5, 10, 21]:
        features_df[f'rolling_mean_{window}'] = features_df[price_col].shift(1).rolling(window).mean()
        features_df[f'rolling_std_{window}'] = features_df[price_col].shift(1).rolling(window).std()
        features_df[f'rolling_min_{window}'] = features_df[price_col].shift(1).rolling(window).min()
        features_df[f'rolling_max_{window}'] = features_df[price_col].shift(1).rolling(window).max()
    
    # Price momentum indicators
    features_df['momentum_5'] = features_df[price_col].shift(1) - features_df[price_col].shift(6)
    features_df['momentum_10'] = features_df[price_col].shift(1) - features_df[price_col].shift(11)
    
    # Rate of change
    features_df['roc_5'] = (features_df[price_col].shift(1) - features_df[price_col].shift(6)) / features_df[price_col].shift(6)
    features_df['roc_10'] = (features_df[price_col].shift(1) - features_df[price_col].shift(11)) / features_df[price_col].shift(11)
    
    # Volatility
    returns = features_df[price_col].pct_change()
    features_df['volatility_5'] = returns.shift(1).rolling(5).std()
    features_df['volatility_10'] = returns.shift(1).rolling(10).std()
    
    # Exponential moving averages
    features_df['ema_5'] = features_df[price_col].shift(1).ewm(span=5, adjust=False).mean()
    features_df['ema_21'] = features_df[price_col].shift(1).ewm(span=21, adjust=False).mean()
    
    # Lagged movements
    for lag in [1, 2, 3, 5]:
        features_df[f'movement_lag_{lag}'] = features_df['movement'].shift(lag)
    
    return features_df

# %%
# Create features
df_features = create_features(df)
df_features = df_features.dropna().reset_index(drop=True)

print(f"Dataset shape after feature engineering: {df_features.shape}")
print(f"Number of features: {df_features.shape[1] - 3}")
# Out:
# Dataset shape after feature engineering: (619, 38)
# Number of features: 35

# %%
# Define horizons
HORIZONS = [1, 5, 21, 63]

# Prepare feature columns
exclude_cols = ['Dates', 'FNCL 6.5 2022 FL Mtge', 'movement', 'price_diff']
feature_cols = [col for col in df_features.columns if col not in exclude_cols]

print(f"Feature columns ({len(feature_cols)}): {feature_cols[:10]}...")
# Out:
# Feature columns (34): ['price_lag_1', 'price_lag_2', 'price_lag_3', 'price_lag_5', 'price_lag_10', 'price_lag_21', 'diff_lag_1', 'diff_lag_2', 'diff_lag_3', 'diff_lag_5']...

# %% [markdown]
# ## Helper Function for Preparing Data

# %%
def create_sequences(X, y, time_steps=10):
    """Create sequences for LSTM"""
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

# %% [markdown]
# ## Define Sequence Model and Attention Block

# %%
def attention_block(inputs):
    """
    Implements an attention mechanism for the LSTM model.
    """
    attention = Dense(1, activation='tanh')(inputs)
    attention = Softmax(axis=1)(attention)
    attention = Multiply()([inputs, attention])
    return attention

# %%
def build_bilstm_attention_model(input_shape):
    inputs = Input(shape=input_shape)
    
    # First BiLSTM layer
    x = Bidirectional(LSTM(128, return_sequences=True))(inputs)
    x = Dropout(0.3)(x)
    
    # Second BiLSTM layer
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    x = Dropout(0.3)(x)
    
    # Attention mechanism
    x = attention_block(x)
    
    # Third BiLSTM layer
    x = Bidirectional(LSTM(32, return_sequences=False))(x)
    x = Dropout(0.3)(x)
    
    # Dense layers
    x = Dense(32, activation='relu')(x)
    x = Dropout(0.2)(x)
    x = Dense(16, activation='relu')(x)
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# ## Model Training and Evaluation

# %%
# Results storage
results = []

# Train and evaluate models for each horizon
for horizon in HORIZONS:
    print(f"HORIZON: {horizon} days ahead")
    
    # Create target
    y_target = df_features['movement'].shift(-horizon)
    
    # Remove NaN values
    valid_idx = y_target.notna()
    X_data = df_features[feature_cols][valid_idx].values
    y_data = y_target[valid_idx].values
    
    # Train-test split (80-20)
    split_idx = int(len(X_data) * 0.8)
    X_train, X_test = X_data[:split_idx], X_data[split_idx:]
    y_train, y_test = y_data[:split_idx], y_data[split_idx:]
    
    print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")
    
    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # BiLSTM with Attention
    time_steps = 15  # Increased time steps for better context
    
    X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train, time_steps)
    X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test, time_steps)
    
    print(f"Sequence shape - Train: {X_train_seq.shape}, Test: {X_test_seq.shape}")
    
    bilstm_model = build_bilstm_attention_model((time_steps, X_train_scaled.shape[1]))
    
    # Enhanced callbacks
    early_stop = EarlyStopping(monitor='loss', patience=15, restore_best_weights=True, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)
    
    bilstm_model.fit(
        X_train_seq, y_train_seq,
        epochs=100,
        batch_size=32,
        verbose=1,
        callbacks=[early_stop, reduce_lr]
    )
    
    # Predictions
    y_pred_bilstm = (bilstm_model.predict(X_test_seq, verbose=0) > 0.5).astype(int).flatten()
    
    # Metrics
    acc_bilstm = accuracy_score(y_test_seq, y_pred_bilstm)
    prec_up_bilstm = precision_score(y_test_seq, y_pred_bilstm, pos_label=1, zero_division=0)
    prec_down_bilstm = precision_score(y_test_seq, y_pred_bilstm, pos_label=0, zero_division=0)
    f1_up_bilstm = f1_score(y_test_seq, y_pred_bilstm, pos_label=1, zero_division=0)
    f1_down_bilstm = f1_score(y_test_seq, y_pred_bilstm, pos_label=0, zero_division=0)
    recall_up_bilstm = recall_score(y_test_seq, y_pred_bilstm, pos_label=1, zero_division=0)
    recall_down_bilstm = recall_score(y_test_seq, y_pred_bilstm, pos_label=0, zero_division=0)
    
    print(f"\nAccuracy: {acc_bilstm:.4f}")
    print(f"Precision (Up): {prec_up_bilstm:.4f}, Precision (Down): {prec_down_bilstm:.4f}")
    print(f"Recall (Up): {recall_up_bilstm:.4f}, Recall (Down): {recall_down_bilstm:.4f}")
    print(f"F1-Score (Up): {f1_up_bilstm:.4f}, F1-Score (Down): {f1_down_bilstm:.4f}")
    
    results.append({
        'Horizon': horizon,
        'Model': 'BiLSTM+Attention',
        'Accuracy': acc_bilstm,
        'Precision_Up': prec_up_bilstm,
        'Precision_Down': prec_down_bilstm,
        'Recall_Up': recall_up_bilstm,
        'Recall_Down': recall_down_bilstm,
        'F1_Up': f1_up_bilstm,
        'F1_Down': f1_down_bilstm
    })
# Out:
# HORIZON: 1 days ahead
# Train size: 494, Test size: 124
# Sequence shape - Train: (479, 15, 34), Test: (109, 15, 34)
# 2025-11-21 15:53:57.240979: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/100
# 2025-11-21 15:53:57.599795: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - accuracy: 0.5015 - loss: 0.6944 - learning_rate: 0.0010
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5053 - loss: 0.6922 - learning_rate: 0.0010
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5221 - loss: 0.6922 - learning_rate: 0.0010
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4852 - loss: 0.6947 - learning_rate: 0.0010
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5203 - loss: 0.6921 - learning_rate: 0.0010
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5497 - loss: 0.6922 - learning_rate: 0.0010
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8887 - loss: 0.3111 - learning_rate: 0.0010
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8858 - loss: 0.2897 - learning_rate: 0.0010
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8416 - loss: 0.3330 - learning_rate: 0.0010
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9123 - loss: 0.2387 - learning_rate: 0.0010
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9265 - loss: 0.1946 - learning_rate: 0.0010
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9382 - loss: 0.1680 - learning_rate: 0.0010
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9254 - loss: 0.2069 - learning_rate: 0.0010
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9227 - loss: 0.1911 - learning_rate: 0.0010
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9021 - loss: 0.2485 - learning_rate: 0.0010
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8532 - loss: 0.3208 - learning_rate: 0.0010
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9023 - loss: 0.2760
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9019 - loss: 0.2759 - learning_rate: 0.0010
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9218 - loss: 0.2320 - learning_rate: 5.0000e-04
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9564 - loss: 0.1422 - learning_rate: 5.0000e-04
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9570 - loss: 0.1302 - learning_rate: 5.0000e-04
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9705 - loss: 0.0927 - learning_rate: 5.0000e-04
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9770 - loss: 0.0719 - learning_rate: 5.0000e-04
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9755 - loss: 0.0843 - learning_rate: 5.0000e-04
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9852 - loss: 0.0478 - learning_rate: 5.0000e-04
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9815 - loss: 0.0621 - learning_rate: 5.0000e-04
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9731 - loss: 0.0768 - learning_rate: 5.0000e-04
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9595 - loss: 0.1094 - learning_rate: 5.0000e-04
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9735 - loss: 0.0706 - learning_rate: 5.0000e-04
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9802 - loss: 0.0600 - learning_rate: 5.0000e-04
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9925 - loss: 0.0310 - learning_rate: 5.0000e-04
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9919 - loss: 0.0374 - learning_rate: 5.0000e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9946 - loss: 0.0303 - learning_rate: 5.0000e-04
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9873 - loss: 0.0337 - learning_rate: 5.0000e-04
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9885 - loss: 0.0291 - learning_rate: 5.0000e-04
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9890 - loss: 0.0421
# Epoch 90: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9884 - loss: 0.0444 - learning_rate: 5.0000e-04
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9779 - loss: 0.0625 - learning_rate: 2.5000e-04
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9963 - loss: 0.0198 - learning_rate: 2.5000e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9989 - loss: 0.0155 - learning_rate: 2.5000e-04
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9953 - loss: 0.0161 - learning_rate: 2.5000e-04
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0079 - learning_rate: 2.5000e-04
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9994 - loss: 0.0075 - learning_rate: 2.5000e-04
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9993 - loss: 0.0055 - learning_rate: 2.5000e-04
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9978 - loss: 0.0058 - learning_rate: 2.5000e-04
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0048 - learning_rate: 2.5000e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9978 - loss: 0.0054 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 99.
# 2025-11-21 15:55:22.350136: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# Accuracy: 0.4862
# Precision (Up): 0.5161, Precision (Down): 0.4744
# Recall (Up): 0.2807, Recall (Down): 0.7115
# F1-Score (Up): 0.3636, F1-Score (Down): 0.5692
# HORIZON: 5 days ahead
# Train size: 491, Test size: 123
# Sequence shape - Train: (476, 15, 34), Test: (108, 15, 34)
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.5230 - loss: 0.6938 - learning_rate: 0.0010
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.4940 - loss: 0.6932 - learning_rate: 0.0010
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4895 - loss: 0.6938 - learning_rate: 0.0010
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5235 - loss: 0.6928 - learning_rate: 0.0010
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8007 - loss: 0.3981 - learning_rate: 0.0010
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8406 - loss: 0.3399 - learning_rate: 0.0010
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8335 - loss: 0.3641 - learning_rate: 0.0010
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8361 - loss: 0.4071 - learning_rate: 0.0010
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8312 - loss: 0.3788 - learning_rate: 0.0010
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8237 - loss: 0.3327 - learning_rate: 0.0010
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8559 - loss: 0.3199 - learning_rate: 0.0010
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8275 - loss: 0.3706 - learning_rate: 0.0010
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8720 - loss: 0.3099 - learning_rate: 0.0010
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8613 - loss: 0.2813 - learning_rate: 0.0010
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8833 - loss: 0.2844 - learning_rate: 0.0010
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8653 - loss: 0.3387 - learning_rate: 0.0010
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8753 - loss: 0.2763 - learning_rate: 0.0010
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8734 - loss: 0.2727 - learning_rate: 0.0010
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8529 - loss: 0.3346
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8534 - loss: 0.3337 - learning_rate: 0.0010
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8736 - loss: 0.2755 - learning_rate: 5.0000e-04
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8843 - loss: 0.2419 - learning_rate: 5.0000e-04
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8976 - loss: 0.2194 - learning_rate: 5.0000e-04
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9249 - loss: 0.1776 - learning_rate: 5.0000e-04
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9386 - loss: 0.1696 - learning_rate: 5.0000e-04
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9492 - loss: 0.1500 - learning_rate: 5.0000e-04
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9382 - loss: 0.1514 - learning_rate: 5.0000e-04
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9410 - loss: 0.1557 - learning_rate: 5.0000e-04
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9370 - loss: 0.1562 - learning_rate: 5.0000e-04
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9309 - loss: 0.1852 - learning_rate: 5.0000e-04
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9033 - loss: 0.2226
# Epoch 85: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9043 - loss: 0.2208 - learning_rate: 5.0000e-04
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9429 - loss: 0.1676 - learning_rate: 2.5000e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9459 - loss: 0.1526 - learning_rate: 2.5000e-04
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9514 - loss: 0.1329 - learning_rate: 2.5000e-04
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9561 - loss: 0.1153 - learning_rate: 2.5000e-04
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9532 - loss: 0.1177 - learning_rate: 2.5000e-04
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9544 - loss: 0.1037 - learning_rate: 2.5000e-04
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9516 - loss: 0.1064 - learning_rate: 2.5000e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9724 - loss: 0.0987 - learning_rate: 2.5000e-04
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9712 - loss: 0.0824 - learning_rate: 2.5000e-04
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9748 - loss: 0.0740 - learning_rate: 2.5000e-04
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9706 - loss: 0.0749 - learning_rate: 2.5000e-04
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9754 - loss: 0.0752 - learning_rate: 2.5000e-04
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9707 - loss: 0.0682 - learning_rate: 2.5000e-04
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9847 - loss: 0.0534 - learning_rate: 2.5000e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9842 - loss: 0.0667 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 99.
# 2025-11-21 15:56:52.103078: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# Accuracy: 0.4537
# Precision (Up): 0.4783, Precision (Down): 0.4355
# Recall (Up): 0.3860, Recall (Down): 0.5294
# F1-Score (Up): 0.4272, F1-Score (Down): 0.4779
# HORIZON: 21 days ahead
# Train size: 478, Test size: 120
# Sequence shape - Train: (463, 15, 34), Test: (105, 15, 34)
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.4351 - loss: 0.6935 - learning_rate: 0.0010
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.5196 - loss: 0.6928 - learning_rate: 0.0010
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7382 - loss: 0.5071 - learning_rate: 0.0010
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7959 - loss: 0.4210 - learning_rate: 0.0010
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8049 - loss: 0.4225
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8079 - loss: 0.4177 - learning_rate: 0.0010
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7997 - loss: 0.3935 - learning_rate: 5.0000e-04
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8424 - loss: 0.3537 - learning_rate: 5.0000e-04
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8585 - loss: 0.2991 - learning_rate: 5.0000e-04
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8795 - loss: 0.2532 - learning_rate: 5.0000e-04
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8847 - loss: 0.2565 - learning_rate: 5.0000e-04
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9183 - loss: 0.1920 - learning_rate: 5.0000e-04
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9054 - loss: 0.2025 - learning_rate: 5.0000e-04
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9183 - loss: 0.1718 - learning_rate: 5.0000e-04
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9156 - loss: 0.1887 - learning_rate: 5.0000e-04
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9477 - loss: 0.1640 - learning_rate: 5.0000e-04
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9478 - loss: 0.1356 - learning_rate: 5.0000e-04
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9425 - loss: 0.1328 - learning_rate: 5.0000e-04
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9299 - loss: 0.1610 - learning_rate: 5.0000e-04
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9382 - loss: 0.1381 - learning_rate: 5.0000e-04
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9516 - loss: 0.1474 - learning_rate: 5.0000e-04
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9512 - loss: 0.1814
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9516 - loss: 0.1787 - learning_rate: 5.0000e-04
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9684 - loss: 0.0928 - learning_rate: 2.5000e-04
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9765 - loss: 0.0748 - learning_rate: 2.5000e-04
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9773 - loss: 0.0681 - learning_rate: 2.5000e-04
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9918 - loss: 0.0464 - learning_rate: 2.5000e-04
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9892 - loss: 0.0455 - learning_rate: 2.5000e-04
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9779 - loss: 0.0459 - learning_rate: 2.5000e-04
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9843 - loss: 0.0466 - learning_rate: 2.5000e-04
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9838 - loss: 0.0452 - learning_rate: 2.5000e-04
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9858 - loss: 0.0444 - learning_rate: 2.5000e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9917 - loss: 0.0377 - learning_rate: 2.5000e-04
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9853 - loss: 0.0400 - learning_rate: 2.5000e-04
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9786 - loss: 0.0377 - learning_rate: 2.5000e-04
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9857 - loss: 0.0402 - learning_rate: 2.5000e-04
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9835 - loss: 0.0527 - learning_rate: 2.5000e-04
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9661 - loss: 0.0720 - learning_rate: 2.5000e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9669 - loss: 0.0974
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9675 - loss: 0.0958 - learning_rate: 2.5000e-04
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9715 - loss: 0.0798 - learning_rate: 1.2500e-04
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9808 - loss: 0.0434 - learning_rate: 1.2500e-04
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9882 - loss: 0.0373 - learning_rate: 1.2500e-04
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9904 - loss: 0.0208 - learning_rate: 1.2500e-04
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0134 - learning_rate: 1.2500e-04
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9878 - loss: 0.0277 - learning_rate: 1.2500e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9906 - loss: 0.0220 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 98.
# 2025-11-21 15:58:19.236366: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b5633408fe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b5633408fe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Accuracy: 0.6095
# Precision (Up): 0.6190, Precision (Down): 0.5952
# Recall (Up): 0.6964, Recall (Down): 0.5102
# F1-Score (Up): 0.6555, F1-Score (Down): 0.5495
# HORIZON: 63 days ahead
# Train size: 444, Test size: 112
# Sequence shape - Train: (429, 15, 34), Test: (97, 15, 34)
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.5336 - loss: 0.6933 - learning_rate: 0.0010
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5736 - loss: 0.6913 - learning_rate: 0.0010
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5511 - loss: 0.6906 - learning_rate: 0.0010
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5772 - loss: 0.6892 - learning_rate: 0.0010
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5896 - loss: 0.6852 - learning_rate: 0.0010
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.5905 - loss: 0.6864 - learning_rate: 0.0010
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5747 - loss: 0.6835 - learning_rate: 0.0010
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5775 - loss: 0.6817 - learning_rate: 0.0010
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6054 - loss: 0.6849 - learning_rate: 0.0010
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5581 - loss: 0.6855 - learning_rate: 0.0010
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5840 - loss: 0.6828 - learning_rate: 0.0010
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5267 - loss: 0.6847 - learning_rate: 0.0010
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5635 - loss: 0.6772 - learning_rate: 0.0010
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5845 - loss: 0.6768 - learning_rate: 0.0010
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5676 - loss: 0.6898 - learning_rate: 0.0010
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5190 - loss: 0.6742 - learning_rate: 0.0010
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5619 - loss: 0.6768 - learning_rate: 0.0010
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5774 - loss: 0.6625 - learning_rate: 0.0010
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5554 - loss: 0.6744 - learning_rate: 0.0010
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5388 - loss: 0.6770 - learning_rate: 0.0010
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6138 - loss: 0.6606 - learning_rate: 0.0010
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6013 - loss: 0.6543 - learning_rate: 0.0010
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5813 - loss: 0.6535 - learning_rate: 0.0010
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5647 - loss: 0.6529 - learning_rate: 0.0010
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6065 - loss: 0.6501 - learning_rate: 0.0010
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6194 - loss: 0.6383 - learning_rate: 0.0010
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6109 - loss: 0.6450 - learning_rate: 0.0010
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5642 - loss: 0.6386 - learning_rate: 0.0010
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5694 - loss: 0.6350 - learning_rate: 0.0010
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5910 - loss: 0.6356 - learning_rate: 0.0010
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5427 - loss: 0.6393 - learning_rate: 0.0010
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6053 - loss: 0.6514 - learning_rate: 0.0010
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5944 - loss: 0.6442 - learning_rate: 0.0010
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6173 - loss: 0.6114 - learning_rate: 0.0010
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6199 - loss: 0.6139 - learning_rate: 0.0010
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6178 - loss: 0.6023 - learning_rate: 0.0010
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6210 - loss: 0.5915 - learning_rate: 0.0010
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6241 - loss: 0.6082 - learning_rate: 0.0010
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6443 - loss: 0.5833 - learning_rate: 0.0010
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6455 - loss: 0.5651 - learning_rate: 0.0010
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6627 - loss: 0.5644 - learning_rate: 0.0010
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6313 - loss: 0.5596 - learning_rate: 0.0010
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6253 - loss: 0.5423 - learning_rate: 0.0010
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6705 - loss: 0.5276 - learning_rate: 0.0010
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6343 - loss: 0.5485 - learning_rate: 0.0010
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6252 - loss: 0.6065 - learning_rate: 0.0010
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5996 - loss: 0.6220 - learning_rate: 0.0010
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6330 - loss: 0.5935 - learning_rate: 0.0010
# Epoch 49/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6458 - loss: 0.5669
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6520 - loss: 0.5615 - learning_rate: 0.0010
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6775 - loss: 0.5614 - learning_rate: 5.0000e-04
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6682 - loss: 0.5407 - learning_rate: 5.0000e-04
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6478 - loss: 0.5420 - learning_rate: 5.0000e-04
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6817 - loss: 0.4996 - learning_rate: 5.0000e-04
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6753 - loss: 0.4943 - learning_rate: 5.0000e-04
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6698 - loss: 0.4697 - learning_rate: 5.0000e-04
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6978 - loss: 0.4847 - learning_rate: 5.0000e-04
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6976 - loss: 0.4677 - learning_rate: 5.0000e-04
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7099 - loss: 0.4781 - learning_rate: 5.0000e-04
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7054 - loss: 0.4944 - learning_rate: 5.0000e-04
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6666 - loss: 0.4965 - learning_rate: 5.0000e-04
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6792 - loss: 0.5053 - learning_rate: 5.0000e-04
# Epoch 62/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6782 - loss: 0.4810
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6838 - loss: 0.4760 - learning_rate: 5.0000e-04
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7104 - loss: 0.4428 - learning_rate: 2.5000e-04
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.7514 - loss: 0.4291 - learning_rate: 2.5000e-04
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7708 - loss: 0.4146 - learning_rate: 2.5000e-04
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7670 - loss: 0.4115 - learning_rate: 2.5000e-04
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7779 - loss: 0.4023 - learning_rate: 2.5000e-04
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7585 - loss: 0.3828 - learning_rate: 2.5000e-04
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7737 - loss: 0.3825 - learning_rate: 2.5000e-04
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7636 - loss: 0.3703 - learning_rate: 2.5000e-04
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7974 - loss: 0.3523 - learning_rate: 2.5000e-04
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7939 - loss: 0.3624 - learning_rate: 2.5000e-04
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7797 - loss: 0.3512 - learning_rate: 2.5000e-04
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8058 - loss: 0.3252 - learning_rate: 2.5000e-04
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8039 - loss: 0.3349 - learning_rate: 2.5000e-04
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8053 - loss: 0.3300 - learning_rate: 2.5000e-04
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8008 - loss: 0.3290 - learning_rate: 2.5000e-04
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8152 - loss: 0.3214 - learning_rate: 2.5000e-04
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7927 - loss: 0.3631 - learning_rate: 2.5000e-04
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7751 - loss: 0.3660 - learning_rate: 2.5000e-04
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7725 - loss: 0.3633 - learning_rate: 2.5000e-04
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7840 - loss: 0.3837 - learning_rate: 2.5000e-04
# Epoch 83/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7817 - loss: 0.3678
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7866 - loss: 0.3621 - learning_rate: 2.5000e-04
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7896 - loss: 0.3359 - learning_rate: 1.2500e-04
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7997 - loss: 0.3270 - learning_rate: 1.2500e-04
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7904 - loss: 0.3190 - learning_rate: 1.2500e-04
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7929 - loss: 0.3247 - learning_rate: 1.2500e-04
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7975 - loss: 0.3179 - learning_rate: 1.2500e-04
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8025 - loss: 0.3127 - learning_rate: 1.2500e-04
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8033 - loss: 0.3114 - learning_rate: 1.2500e-04
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7916 - loss: 0.3272 - learning_rate: 1.2500e-04
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8086 - loss: 0.3105 - learning_rate: 1.2500e-04
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7906 - loss: 0.3110 - learning_rate: 1.2500e-04
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8018 - loss: 0.3161 - learning_rate: 1.2500e-04
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8050 - loss: 0.3218 - learning_rate: 1.2500e-04
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8159 - loss: 0.3021 - learning_rate: 1.2500e-04
# Epoch 97/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8009 - loss: 0.3153
# Epoch 97: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8054 - loss: 0.3106 - learning_rate: 1.2500e-04
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7981 - loss: 0.3281 - learning_rate: 6.2500e-05
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7971 - loss: 0.3090 - learning_rate: 6.2500e-05
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8121 - loss: 0.2915 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 100.
# 2025-11-21 15:59:41.892622: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# Accuracy: 0.5258
# Precision (Up): 0.5172, Precision (Down): 0.6000
# Recall (Up): 0.9184, Recall (Down): 0.1250
# F1-Score (Up): 0.6618, F1-Score (Down): 0.2069

# %%
results_df = pd.DataFrame(results)
display(results_df)
# Out:
#    Horizon             Model  Accuracy  Precision_Up  Precision_Down  \
# 0        1  BiLSTM+Attention  0.486239      0.516129        0.474359
# 1        5  BiLSTM+Attention  0.453704      0.478261        0.435484
# 2       21  BiLSTM+Attention  0.609524      0.619048        0.595238
# 3       63  BiLSTM+Attention  0.525773      0.517241        0.600000
#
#    Recall_Up  Recall_Down     F1_Up   F1_Down
# 0   0.280702     0.711538  0.363636  0.569231
# 1   0.385965     0.529412  0.427184  0.477876
# 2   0.696429     0.510204  0.655462  0.549451
# 3   0.918367     0.125000  0.661765  0.206897

# %%
# Best models by horizon
# print("Best Model Per Horizon (by Accuracy)")

# for horizon in HORIZONS:
#     horizon_results = results_df[results_df['Horizon'] == horizon]
#     best_model = horizon_results.loc[horizon_results['Accuracy'].idxmax()]
#     print(f"Horizon {horizon}: {best_model['Model']} (Accuracy: {best_model['Accuracy']:.4f}, "
#           f"F1_Up: {best_model['F1_Up']:.4f}, F1_Down: {best_model['F1_Down']:.4f})")
